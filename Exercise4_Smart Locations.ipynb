# %% [markdown]
# # Ejercicio 4 - Smart Recruiting

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Lectura de datos

# %% [raw]
# ...

# %% [markdown]
# ## Exploración de datos

# %% [raw]
# ...

# %% [markdown]
# ## Limpieza

# %% [raw]
# ...

# %% [markdown]
# ## Verificación de datos

# %% [raw]
# df_final.info()

# %% [markdown]
# ![imagen.png](attachment:af47326f-a474-413e-8e5f-dd898cbe0cde.png)

# %% [raw]
# df_final.query("Id == 131478")

# %% [markdown]
# ![imagen.png](attachment:2db62c83-fc04-449d-8a9d-201b5078c13d.png)

# %% [raw]
# df_final.describe(include = 'all')

# %% [markdown]
# ![imagen.png](attachment:a3e8c06b-7d72-42dc-9aac-97b9bd4fb159.png)

# %% [raw]
# ( df_final
#   .query("Id < 50000")
#   .groupby("Id").aggregate(["count"])
# )

# %% [markdown]
# ![imagen.png](attachment:4ea10dc5-8d9b-4b87-9ff9-cbad1131a01c.png)
